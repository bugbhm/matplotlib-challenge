# %%
#dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
#read csv files
mouse_drug = pd.read_csv("mouse_drug_data.csv")
clinical_trial = pd.read_csv("clinicaltrial_data.csv")

# %%
#merge on Mouse ID
drug_data = pd.merge(clinical_trial, mouse_drug, on = 'Mouse ID', how = 'left')
drug_data.head(5)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0                45.0                 0  Capomulin
# 1     f932          0                45.0                 0   Ketapril
# 2     g107          0                45.0                 0   Ketapril
# 3     a457          0                45.0                 0   Ketapril
# 4     c819          0                45.0                 0   Ketapril

# %% [markdown]
# # Tumor Volume After Treatement

# %%
#group by drug and find average tumor volume
drugs_grouped = drug_data.groupby(['Drug', 'Timepoint'])
avg_tumor_vol = drugs_grouped.mean()['Tumor Volume (mm3)']

#reset index
avg_tumor_vol = avg_tumor_vol.reset_index()
avg_tumor_vol
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# ..        ...        ...                 ...
# 95  Zoniferol         25           55.432935
# 96  Zoniferol         30           57.713531
# 97  Zoniferol         35           60.089372
# 98  Zoniferol         40           62.916692
# 99  Zoniferol         45           65.960888
#
# [100 rows x 3 columns]

# %%
# find standard error of tumor vol
se_tumor_vol = drugs_grouped.sem()["Tumor Volume (mm3)"]
se_tumor_change = pd.DataFrame(se_tumor_vol)

se_tumor_change = se_tumor_change.reset_index()
se_tumor_change.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
#munging
tumor_vol_df = avg_tumor_vol.pivot(index= 'Timepoint', columns='Drug', values='Tumor Volume (mm3)')
tumor_vol_df = pd.DataFrame(tumor_vol_df)

tumor_vol_df.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# plot change in tumor vol
fig, ax = plt.subplots(figsize=(12,5))
x_axis = tumor_vol_df.index.values
markers = ['o','o','o','o','o','o','o','o','o','o']
colors = ['red', 'blue', 'green', 'yellow', 'magenta', 'cyan', 'orange', 'limegreen', 'grey', 'black']

#loop
i = 0
for drug in tumor_vol_df.columns:
    y_axis = tumor_vol_df[drug].values
    standard_errors = se_tumor_change[se_tumor_change.Drug == drug]['Tumor Volume (mm3)'].values
    ax.errorbar(x_axis, y_axis, standard_errors, label=drug, linestyle='solid', marker=markers[i], color=colors[i])
    i += 1

plt.title("Tumor Changes After Drug")
plt.xlabel("Timepoints")
plt.ylabel("Tumor Volume")
plt.legend(loc='upperleft')
plt.grid()

# save chart
plt.savefig('tumor_changes.png')

# %% [markdown]
# # Change in Metastatic Sites

# %%
# find avg change in metastatic sites
avg_meta_response = drugs_grouped.mean()['Metastatic Sites']
avg_meta_change = pd.DataFrame(avg_meta_response)

avg_meta_change = avg_meta_change.reset_index()
avg_meta_change.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.160000
# 2  Capomulin         10          0.320000
# 3  Capomulin         15          0.375000
# 4  Capomulin         20          0.652174

# %%
# find standard error
se_meta_vol = drugs_grouped.sem()['Metastatic Sites']
se_meta_change = pd.DataFrame(se_meta_vol)

se_meta_change = se_meta_change.reset_index()
se_meta_change.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.074833
# 2  Capomulin         10          0.125433
# 3  Capomulin         15          0.132048
# 4  Capomulin         20          0.161621

# %%
#munging
meta_vol_df = avg_meta_change.pivot(index= 'Timepoint', columns='Drug', values='Metastatic Sites')
meta_vol_df = pd.DataFrame(meta_vol_df)

meta_vol_df.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118

# %%
#plot
fig, ax = plt.subplots(figsize=(12,5))
x_axis_meta = meta_vol_df.index.values

# loop
i = 0
for drug in meta_vol_df.columns:
    y_axis_meta = meta_vol_df[drug].values
    standard_errors = se_meta_change[se_meta_change.Drug == drug]['Metastatic Sites'].values
    ax.errorbar(x_axis_meta, y_axis_meta, standard_errors, label=drug, linestyle='solid', marker=markers[i], color=colors[i])
    i += 1

plt.title("Metstatic Site Changes After Drug")
plt.xlabel("Timepoints")
plt.ylabel("Number of Metstatic Sites")
plt.legend(loc='upperleft')
plt.grid()

# Save the Figure
plt.savefig('meta_site_changes.png')

# %% [markdown]
# # Survival Rates

# %%
# find survival rate
mouse_survival_rates = drugs_grouped.count()['Mouse ID']
survival_rates_df = pd.DataFrame(mouse_survival_rates)

survival_rates_df = survival_rates_df.reset_index()
survival_rates_df.head()
# Out:
#         Drug  Timepoint  Mouse ID
# 0  Capomulin          0        25
# 1  Capomulin          5        25
# 2  Capomulin         10        25
# 3  Capomulin         15        24
# 4  Capomulin         20        23

# %%
# munging
survival_df = survival_rates_df.pivot(index='Timepoint', columns='Drug', values='Mouse ID')
survival_df.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# plot
fig, ax = plt.subplots(figsize=(12,5))
x_axis_mice  = survival_df.index.values

# loop
i = 0
for drug in survival_df.columns:
    y_axis_mice = survival_df[drug].values
    ax.errorbar(x_axis_mice, y_axis_mice, standard_errors, label=drug, linestyle='solid', marker=markers[i], color=colors[i])
    i += 1

plt.title("Survival Rates")
plt.xlabel("Timepoints")
plt.ylabel("Number of Living Mice")
plt.legend(loc='lowerleft')
plt.grid()

# Save the Figure
plt.savefig('survival_rate.png')

# %% [markdown]
# # Percent Change/Summary

# %%
# find percent change in vol for each drug
avg_tumor_df = avg_tumor_vol.drop(['Timepoint'], axis=1)
drug_grouped_df = avg_tumor_df.groupby(['Drug'])

# % = last value - first value / first value * 100
percent_changes = (drug_grouped_df['Tumor Volume (mm3)'].last() - drug_grouped_df['Tumor Volume (mm3)'].first()) /\
                drug_grouped_df['Tumor Volume (mm3)'].first() * 100
percent_changes
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# Name: Tumor Volume (mm3), dtype: float64

# %%
#find percent changes
percent_changes = percent_changes.sort_values(ascending=True)

failing_drug = percent_changes[percent_changes < 0].sort_values(ascending=True)
passing_drug = percent_changes[percent_changes > 0].sort_values(ascending=True)

# label percentages of changes
plt.figure(figsize=(14,4))

negative_axis = plt.bar(failing_drug.index.values, failing_drug.values, color='green', width=1)
positive_axis = plt.bar(passing_drug.index.values, passing_drug.values, color='red', width=1)

# label chart
plt.title("Tumor Change Throughout Treatment")
plt.ylabel("Percent Tumor Volume Change")
plt.xlim(-0.7,len(percent_changes)-0.3)
plt.ylim(-30,70)
plt.grid()

# find negative changes
negative_changes = negative_axis.patches
for change in negative_changes:
    y_value = change.get_height()
    x_value =change.get_x() + change.get_width() / 2
    percentY = str(int(y_value)) + '%'
    plt.text(x_value-0.1, -5, percentY, color='w')

# find postive changes
positive_changes = positive_axis.patches
for change in positive_changes:
    y_value = change.get_height()
    x_value = change.get_x() + change.get_width() / 2
    percentY = str(int(y_value)) + '%'
    plt.text(x_value-0.1, 5, percentY, color='w')

# Save the Figure
plt.savefig("total_tumor_vol_change.png")
